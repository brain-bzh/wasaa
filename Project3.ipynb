# %% [markdown]
# WASAA 2023 - Ressources for project 3
# --

# %% [markdown]
# Decode brain activity during tasks

# %% [markdown]
# We will use the data from [this paper](https://journals.plos.org/plosbiology/article?id=10.1371/journal.pbio.1002180), which used images with High and Low emotional content (the [International Affective Picture System](https://www.sciencedirect.com/science/article/pii/S0165178115001845?via%3Dihub)).
#
# The goal of the project is to use supervised learning to decode the brain response associated with ratings of emotions.

# %% [markdown]
# Dataset download
# --

# %% [markdown]
# The following cell will download the dataset, and downsample it so that the images take less space, and are also easier to classify. This cell will be quite long.
#
# - the `data_dir` argument should be changed. There are only two relevant options : using the network drive (`data_dir = '/homes/yourlogin/'` or just `./` if you downloaded this notebook in the folder Téléchargements) or using the drive of the local machine you are using `data_dir = '/users/local/'`. Local drive will be faster and you have a lot more space, but you'll have to download again if you switch to another machine
#
# You can launch this cell, and while it downloads / resample, you can open another notebook and practice using the Decoder and FREM methods using nilearn tutorials (see below for links).

# %%
from nilearn.datasets import fetch_neurovault_ids

# %%
# %%time
IAPSdata  = fetch_neurovault_ids(collection_ids=[503],data_dir='/home/nfarrugi/datasets/PINESfMRI/',resample=True)
# Out:
# Dataset created in /home/nfarrugi/datasets/PINESfMRI/neurovault
#
# Reading local neurovault data.
# No image found on local disk.
# Reading server neurovault data.
# getting new batch: http://neurovault.org/api/collections/503
# Scroll images from collection 503: getting new batch: http://neurovault.org/api/collections/503/images/?limit=100&offset=0
# Scroll images from collection 503: batch size: 100
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_102_Image_9252.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_41587188-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 1 image
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_102_Image_9300.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_434f3f8a-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 2 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_102_Image_9921.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_4535f226-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 3 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_103_Image_3102.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_48078974-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 4 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_103_Image_7040.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_49dca842-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 5 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_103_Image_7060.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_4bb7f590-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 6 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_103_Image_7217.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_4e328b1e-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 7 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_103_Image_9252.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_506f1c1c-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 8 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_103_Image_9921.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_52585af2-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 9 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_104_Image_2053.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_54576438-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 10 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_104_Image_7130.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_5647fe38-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 11 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_105_Image_7040.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_5846cbb0-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 12 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_105_Image_9252.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_5a342558-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 13 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_105_Image_9300.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_5c167a38-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 14 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_105_Image_9400.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_5e0944ce-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 15 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_106_Image_3051.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_5ff68a3a-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 16 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_106_Image_3500.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_61dba8e4-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 17 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_107_Image_3051.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_63fc0e0c-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 18 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_107_Image_3102.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_65feaf84-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 19 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_107_Image_7006.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_68327682-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 20 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_107_Image_9210.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_6a397110-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 21 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_108_Image_3500.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_6c51cbaa-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 22 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_108_Image_5800.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_6e32ac8c-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 23 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_109_Image_3550.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_700e2874-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 24 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_109_Image_7130.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_71f7814e-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 25 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_111_Image_3550.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_742dda62-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 26 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_111_Image_7500.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_76d4f890-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 27 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_112_Image_5720.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_78db2aec-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 28 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_114_Image_3350.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_7af9bd0c-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 29 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_114_Image_7006.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_7cea1f3a-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 30 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_114_Image_9210.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_7eccbae2-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 31 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_114_Image_9921.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_80c3859c-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 32 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_116_Image_2053.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_83052dec-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 33 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_116_Image_6831.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_84ff0b9a-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 34 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_116_Image_7060.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_8732526e-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 35 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_116_Image_9040.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_89a63182-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 36 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_117_Image_3102.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_8b985420-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 37 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_117_Image_7150.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_8d808776-9cae-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 38 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_117_Image_9400.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp
nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_b7bd4df6-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 301 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_134_Image_9400.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_b9b39c00-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 302 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_134_Image_9810.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_bb9a1fe4-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 303 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_2053.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_bd8b5b56-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 304 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_3051.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_bf779196-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 305 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_3102.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_c167005e-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 306 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_3120.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_c356b9b8-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 307 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_3500.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_c53c7fec-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 308 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_3550.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_c74f2fe6-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 309 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_5720.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_c94126a6-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 310 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_6831.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_cb7e80da-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 311 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_7000.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_ce03fea2-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 312 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_7006.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_d0fd6652-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 313 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_7040.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_d2cf134a-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 314 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_7060.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_d4a2d2ce-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 315 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_7090.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_d6749b46-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 316 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_7100.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_d8fe715c-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 317 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_7150.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_db5aa15a-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 318 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_7217.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_dd773fa2-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 319 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_7490.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_df783360-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 320 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_7500.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_e1c6a494-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 321 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_9040.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_e3d4be2e-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 322 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_9050.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_e5e51fce-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 323 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_9210.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_e7e5df16-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 324 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_9252.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_e9f429d4-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 325 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_9300.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_ebbcd0a4-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 326 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_9400.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_edca8a6c-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 327 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_9810.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_f05e4606-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 328 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_140_Image_9921.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_f2ea4f8c-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 329 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_2053.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_f6360618-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 330 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_3102.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_f8b1b478-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 331 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_3120.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_fae5a0ce-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 332 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_3350.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_fd24a98e-9cb0-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 333 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_5800.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_00feba68-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 334 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_7010.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_039ddaa6-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 335 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_7090.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_07f5c870-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 336 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_7217.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_09fb8380-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 337 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_9040.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_0c9f35b4-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 338 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_9050.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_0ed73250-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 339 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_9400.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_10f57e8e-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 340 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_141_Image_9921.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_134acf04-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 341 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_142_Image_3051.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_152ff538-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 342 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_142_Image_3102.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_17156ac2-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 343 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_142_Image_3120.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_18e798fc-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 344 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_142_Image_3350.nii.gz
# Download succeeded, downloaded to: /home/nfarrugi/datasets/PINESfMRI/neurovault/collection_503/tmp_1ab7e40c-9cb1-11ed-9444-61aeea02a79e.nii.gz
# Resampling...
# Already fetched 345 images
# Downloading file: https://neurovault.org/media/images/503/IAPS_Subject_142_Image_3500.nii.gz

# %% [markdown]
# Supervised learning
# --

# %% [markdown]
# More specifically, here are a few objectives you can try to achieve :
#
# - Using data from the whole brain (no parcellation), use feature selection methods to identify the voxels that are the most informative. There are such methods implemented directly in nilearn using the [Decoder](https://nilearn.github.io/stable/modules/generated/nilearn.decoding.Decoder.html#nilearn.decoding.Decoder) method, as well as the recently proposed [FREM](https://nilearn.github.io/stable/modules/generated/nilearn.decoding.FREMClassifier.html#nilearn.decoding.FREMClassifier)
# - The easiest setup is to classify only rating 1 versus rating 5. How much accuracy can you achieve ?
# - Visualize which parts of the brain are the most important to decode each category
# - You can also try to directly solve the Regression task, which consists in predicting the value of rating directly, instead of considering each rating values as categorical (hence unrelated) variables. Regression can be done with [DecoderRegressor](https://nilearn.github.io/stable/modules/generated/nilearn.decoding.DecoderRegressor.html#nilearn.decoding.DecoderRegressor) or the [FREMRegressor](https://nilearn.github.io/stable/modules/generated/nilearn.decoding.FREMRegressor.html#nilearn.decoding.FREMRegressor)
